# %%
cd /content/drive/My Drive/Medium Topic Tagger/Web Scraping/
# Out:
# /content/drive/My Drive/Medium Topic Tagger/Web Scraping

# %%
import requests
from bs4 import BeautifulSoup

# %%
import pandas as pd
import numpy as np

# %%
topics_list=pd.read_csv('topic_names.csv')

# %%
topics_list.head()
# Out:
#   Topic Name                        Topic Link
# 0        Art      https://medium.com/topic/art
# 1      Books    https://medium.com/topic/books
# 2     Comics   https://medium.com/topic/comics
# 3    Fiction  https://medium.com/topic/fiction
# 4       Film     https://medium.com/topic/film

# %%
topic_links=topics_list['Topic Link']

# %%
topic_names=topics_list['Topic Name']

# %%
topic_links=list(topic_links)
topic_names=list(topic_names)

# %%
topic_links
# Out:
# ['https://medium.com/topic/art',
#  'https://medium.com/topic/books',
#  'https://medium.com/topic/comics',
#  'https://medium.com/topic/fiction',
#  'https://medium.com/topic/film',
#  'https://medium.com/topic/gaming',
#  'https://medium.com/topic/humor',
#  'https://medium.com/topic/music',
#  'https://medium.com/topic/nonfiction',
#  'https://medium.com/topic/photography',
#  'https://medium.com/topic/podcasts',
#  'https://medium.com/topic/poetry',
#  'https://medium.com/topic/tv',
#  'https://medium.com/topic/visual-design',
#  'https://medium.com/topic/culture',
#  'https://medium.com/topic/food',
#  'https://medium.com/topic/language',
#  'https://medium.com/topic/makers',
#  'https://medium.com/topic/outdoors',
#  'https://medium.com/topic/pets',
#  'https://medium.com/topic/philosophy',
#  'https://medium.com/topic/sports',
#  'https://medium.com/topic/style',
#  'https://medium.com/topic/travel',
#  'https://medium.com/topic/true-crime',
# ...

# %%
articles_by_topic=[]

# %%
for x in zip(topic_names,topic_links):
  print(x[0])
  topic_page=requests.get(x[1])
  print(topic_page.json())
  break
# Out:
# Art
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-29-fa3fcea47a1a> in <module>()
#       2   print(x[0])
#       3   topic_page=requests.get(x[1])
# ----> 4   print(topic_page.json())
#       5   break
#
# /usr/local/lib/python3.6/dist-packages/requests/models.py in json(self, **kwargs)
#     896                     # used.
#     897                     pass
# --> 898         return complexjson.loads(self.text, **kwargs)
#     899
#     900     @property
#
# /usr/lib/python3.6/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     352             parse_int is None and parse_float is None and
#     353             parse_constant is None and object_pairs_hook is None and not kw):
# --> 354         return _default_decoder.decode(s)
#     355     if cls is None:
# ...

# %%
wsec
# Out:
# []
